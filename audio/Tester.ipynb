# %%
pip install librosa
# Out:
# ...
#      |████████████████████████████████| 214 kB 4.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.2 MB 30.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 377 kB 24.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 56 kB 24.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.1 MB 119.3 MB/s eta 0:00:01
# ...
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23706 sha256=6b4f4f65fd26ed9f13dacc5ea996c9d522ce8eaa1af45d4dfe702d68a6e9cb52
#   Stored in directory: /Users/ronnie/Library/Caches/pip/wheels/e4/76/a4/cfb55573167a1f5bde7d7a348e95e509c64b2c3e8f921932c3
# Successfully built audioread
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import librosa
audio_data = '/Users/ronnie/Python/RL/glassbreak.wav'
x , sr = librosa.load(audio_data)
print(type(x), type(sr))#<class 'numpy.ndarray'> <class 'int'>print(x.shape, sr)#(94316,) 22050
# Out:
# <class 'numpy.ndarray'> <class 'int'>

# %%
librosa.load(audio_data, sr=44100)
# Out:
# (array([0.08197021, 0.5166931 , 0.8742676 , ..., 0.        , 0.        ,
#         0.        ], dtype=float32),
#  44100)

# %%
import IPython.display as ipd
ipd.Audio(audio_data)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
audio_data = '/Users/ronnie/Python/RL/Fire.wav'
x , sr = librosa.load(audio_data)

# %%
librosa.load(audio_data, sr=44100)
# Out:
# (array([ 0.01809692,  0.02655029,  0.02651978, ..., -0.07440186,
#         -0.08450317, -0.0657959 ], dtype=float32),
#  44100)

# %%
ipd.Audio(audio_data)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
audio_data = '/Users/ronnie/Python/RL/Alarmclock.wav'
x , sr = librosa.load(audio_data)
librosa.load(audio_data, sr=44100)
ipd.Audio(audio_data)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
audio_data = '/Users/ronnie/Python/RL/audio_soundscape-0-m0-g0.wav'
x , sr = librosa.load(audio_data)
librosa.load(audio_data, sr=44100)
ipd.Audio(audio_data)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()
